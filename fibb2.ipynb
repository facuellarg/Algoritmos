# %% [markdown]
# importar librerias-

# %%
from time import time
import matplotlib.pyplot as plt

# %% [markdown]
# definir numeros auxiliares para calcular la seria de fibb y el arreglo t donde se guardaran los tiempos

# %%
n1 = 0
n2 = 1
a = 0
t = []

# %% [markdown]
# tomamos el tiempo inicial y calculamos la sucecion

# %%
ti = time()
while(a < 10000):
	n2 = n2+n1
	n1 = n2-n1
	t.append(time()-ti)
	a = a + 1

# %% [markdown]
# finalmente graficamos

# %%
plt.plot(t)
